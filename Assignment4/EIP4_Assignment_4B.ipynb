# %% [markdown]
# <a href="https://colab.research.google.com/github/Aniruddha7/EIP4-Phase1/blob/master/EIP4_Assignment_4B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten, Activation, Softmax
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

# Training parameters
batch_size = 32  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10
subtract_pixel_mean = True
n=3
version = 2

# %%
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# %%
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 40:
        lr *= 0.5e-3
    elif epoch > 30:
        lr *= 1e-3
    elif epoch > 20:
        lr *= 1e-2
    elif epoch > 10:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = Conv2D(10, 1, 1, name='lastlayer')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)

    y = Flatten()(x)
    outputs = Softmax()(y)
    #outputs = Dense(num_classes,
                    #activation='softmax',
                    #kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model


if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)
# Out:
# Learning rate:  0.001
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_10 (InputLayer)           (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 32, 32, 16)   448         input_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_252 (BatchN (None, 32, 32, 16)   64          conv2d_280[0][0]
# __________________________________________________________________________________________________
# activation_252 (Activation)     (None, 32, 32, 16)   0           batch_normalization_252[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 32, 32, 16)   272         activation_252[0][0]
# __________________________________________________________________________________________________
# batch_normalization_253 (BatchN (None, 32, 32, 16)   64          conv2d_281[0][0]
# __________________________________________________________________________________________________
# activation_253 (Activation)     (None, 32, 32, 16)   0           batch_normalization_253[0][0]
# __________________________________________________________________________________________________
# conv2d_282 (Conv2D)             (None, 32, 32, 16)   2320        activation_253[0][0]
# __________________________________________________________________________________________________
# batch_normalization_254 (BatchN (None, 32, 32, 16)   64          conv2d_282[0][0]
# __________________________________________________________________________________________________
# activation_254 (Activation)     (None, 32, 32, 16)   0           batch_normalization_254[0][0]
# __________________________________________________________________________________________________
# conv2d_284 (Conv2D)             (None, 32, 32, 64)   1088        activation_252[0][0]
# __________________________________________________________________________________________________
# conv2d_283 (Conv2D)             (None, 32, 32, 64)   1088        activation_254[0][0]
# __________________________________________________________________________________________________
# add_82 (Add)                    (None, 32, 32, 64)   0           conv2d_284[0][0]
#                                                                  conv2d_283[0][0]
# __________________________________________________________________________________________________
# batch_normalization_255 (BatchN (None, 32, 32, 64)   256         add_82[0][0]
# __________________________________________________________________________________________________
# activation_255 (Activation)     (None, 32, 32, 64)   0           batch_normalization_255[0][0]
# __________________________________________________________________________________________________
# conv2d_285 (Conv2D)             (None, 32, 32, 16)   1040        activation_255[0][0]
# __________________________________________________________________________________________________
# batch_normalization_256 (BatchN (None, 32, 32, 16)   64          conv2d_285[0][0]
# __________________________________________________________________________________________________
# activation_256 (Activation)     (None, 32, 32, 16)   0           batch_normalization_256[0][0]
# __________________________________________________________________________________________________
# conv2d_286 (Conv2D)             (None, 32, 32, 16)   2320        activation_256[0][0]
# __________________________________________________________________________________________________
# batch_normalization_257 (BatchN (None, 32, 32, 16)   64          conv2d_286[0][0]
# __________________________________________________________________________________________________
# activation_257 (Activation)     (None, 32, 32, 16)   0           batch_normalization_257[0][0]
# __________________________________________________________________________________________________
# conv2d_287 (Conv2D)             (None, 32, 32, 64)   1088        activation_257[0][0]
# __________________________________________________________________________________________________
# add_83 (Add)                    (None, 32, 32, 64)   0           add_82[0][0]
#                                                                  conv2d_287[0][0]
# __________________________________________________________________________________________________
# batch_normalization_258 (BatchN (None, 32, 32, 64)   256         add_83[0][0]
# __________________________________________________________________________________________________
# activation_258 (Activation)     (None, 32, 32, 64)   0           batch_normalization_258[0][0]
# __________________________________________________________________________________________________
# conv2d_288 (Conv2D)             (None, 32, 32, 16)   1040        activation_258[0][0]
# __________________________________________________________________________________________________
# batch_normalization_259 (BatchN (None, 32, 32, 16)   64          conv2d_288[0][0]
# __________________________________________________________________________________________________
# activation_259 (Activation)     (None, 32, 32, 16)   0           batch_normalization_259[0][0]
# __________________________________________________________________________________________________
# conv2d_289 (Conv2D)             (None, 32, 32, 16)   2320        activation_259[0][0]
# __________________________________________________________________________________________________
# batch_normalization_260 (BatchN (None, 32, 32, 16)   64          conv2d_289[0][0]
# __________________________________________________________________________________________________
# activation_260 (Activation)     (None, 32, 32, 16)   0           batch_normalization_260[0][0]
# __________________________________________________________________________________________________
# conv2d_290 (Conv2D)             (None, 32, 32, 64)   1088        activation_260[0][0]
# __________________________________________________________________________________________________
# add_84 (Add)                    (None, 32, 32, 64)   0           add_83[0][0]
#                                                                  conv2d_290[0][0]
# __________________________________________________________________________________________________
# batch_normalization_261 (BatchN (None, 32, 32, 64)   256         add_84[0][0]
# __________________________________________________________________________________________________
# activation_261 (Activation)     (None, 32, 32, 64)   0           batch_normalization_261[0][0]
# __________________________________________________________________________________________________
# conv2d_291 (Conv2D)             (None, 16, 16, 64)   4160        activation_261[0][0]
# __________________________________________________________________________________________________
# batch_normalization_262 (BatchN (None, 16, 16, 64)   256         conv2d_291[0][0]
# __________________________________________________________________________________________________
# activation_262 (Activation)     (None, 16, 16, 64)   0           batch_normalization_262[0][0]
# __________________________________________________________________________________________________
# conv2d_292 (Conv2D)             (None, 16, 16, 64)   36928       activation_262[0][0]
# __________________________________________________________________________________________________
# batch_normalization_263 (BatchN (None, 16, 16, 64)   256         conv2d_292[0][0]
# __________________________________________________________________________________________________
# activation_263 (Activation)     (None, 16, 16, 64)   0           batch_normalization_263[0][0]
# __________________________________________________________________________________________________
# conv2d_294 (Conv2D)             (None, 16, 16, 128)  8320        add_84[0][0]
# __________________________________________________________________________________________________
# conv2d_293 (Conv2D)             (None, 16, 16, 128)  8320        activation_263[0][0]
# __________________________________________________________________________________________________
# add_85 (Add)                    (None, 16, 16, 128)  0           conv2d_294[0][0]
#                                                                  conv2d_293[0][0]
# __________________________________________________________________________________________________
# batch_normalization_264 (BatchN (None, 16, 16, 128)  512         add_85[0][0]
# __________________________________________________________________________________________________
# activation_264 (Activation)     (None, 16, 16, 128)  0           batch_normalization_264[0][0]
# __________________________________________________________________________________________________
# conv2d_295 (Conv2D)             (None, 16, 16, 64)   8256        activation_264[0][0]
# __________________________________________________________________________________________________
# batch_normalization_265 (BatchN (None, 16, 16, 64)   256         conv2d_295[0][0]
# __________________________________________________________________________________________________
# activation_265 (Activation)     (None, 16, 16, 64)   0           batch_normalization_265[0][0]
# __________________________________________________________________________________________________
# conv2d_296 (Conv2D)             (None, 16, 16, 64)   36928       activation_265[0][0]
# __________________________________________________________________________________________________
# batch_normalization_266 (BatchN (None, 16, 16, 64)   256         conv2d_296[0][0]
# __________________________________________________________________________________________________
# activation_266 (Activation)     (None, 16, 16, 64)   0           batch_normalization_266[0][0]
# __________________________________________________________________________________________________
# conv2d_297 (Conv2D)             (None, 16, 16, 128)  8320        activation_266[0][0]
# __________________________________________________________________________________________________
# add_86 (Add)                    (None, 16, 16, 128)  0           add_85[0][0]
#                                                                  conv2d_297[0][0]
# __________________________________________________________________________________________________
# batch_normalization_267 (BatchN (None, 16, 16, 128)  512         add_86[0][0]
# __________________________________________________________________________________________________
# activation_267 (Activation)     (None, 16, 16, 128)  0           batch_normalization_267[0][0]
# __________________________________________________________________________________________________
# conv2d_298 (Conv2D)             (None, 16, 16, 64)   8256        activation_267[0][0]
# __________________________________________________________________________________________________
# batch_normalization_268 (BatchN (None, 16, 16, 64)   256         conv2d_298[0][0]
# __________________________________________________________________________________________________
# activation_268 (Activation)     (None, 16, 16, 64)   0           batch_normalization_268[0][0]
# __________________________________________________________________________________________________
# conv2d_299 (Conv2D)             (None, 16, 16, 64)   36928       activation_268[0][0]
# __________________________________________________________________________________________________
# batch_normalization_269 (BatchN (None, 16, 16, 64)   256         conv2d_299[0][0]
# __________________________________________________________________________________________________
# activation_269 (Activation)     (None, 16, 16, 64)   0           batch_normalization_269[0][0]
# __________________________________________________________________________________________________
# conv2d_300 (Conv2D)             (None, 16, 16, 128)  8320        activation_269[0][0]
# __________________________________________________________________________________________________
# add_87 (Add)                    (None, 16, 16, 128)  0           add_86[0][0]
#                                                                  conv2d_300[0][0]
# __________________________________________________________________________________________________
# batch_normalization_270 (BatchN (None, 16, 16, 128)  512         add_87[0][0]
# __________________________________________________________________________________________________
# activation_270 (Activation)     (None, 16, 16, 128)  0           batch_normalization_270[0][0]
# __________________________________________________________________________________________________
# conv2d_301 (Conv2D)             (None, 8, 8, 128)    16512       activation_270[0][0]
# __________________________________________________________________________________________________
# batch_normalization_271 (BatchN (None, 8, 8, 128)    512         conv2d_301[0][0]
# __________________________________________________________________________________________________
# activation_271 (Activation)     (None, 8, 8, 128)    0           batch_normalization_271[0][0]
# __________________________________________________________________________________________________
# conv2d_302 (Conv2D)             (None, 8, 8, 128)    147584      activation_271[0][0]
# __________________________________________________________________________________________________
# batch_normalization_272 (BatchN (None, 8, 8, 128)    512         conv2d_302[0][0]
# __________________________________________________________________________________________________
# activation_272 (Activation)     (None, 8, 8, 128)    0           batch_normalization_272[0][0]
# __________________________________________________________________________________________________
# conv2d_304 (Conv2D)             (None, 8, 8, 256)    33024       add_87[0][0]
# __________________________________________________________________________________________________
# conv2d_303 (Conv2D)             (None, 8, 8, 256)    33024       activation_272[0][0]
# __________________________________________________________________________________________________
# add_88 (Add)                    (None, 8, 8, 256)    0           conv2d_304[0][0]
#                                                                  conv2d_303[0][0]
# __________________________________________________________________________________________________
# batch_normalization_273 (BatchN (None, 8, 8, 256)    1024        add_88[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 8, 8, 256)    0           batch_normalization_273[0][0]
# __________________________________________________________________________________________________
# conv2d_305 (Conv2D)             (None, 8, 8, 128)    32896       activation_273[0][0]
# __________________________________________________________________________________________________
# batch_normalization_274 (BatchN (None, 8, 8, 128)    512         conv2d_305[0][0]
# __________________________________________________________________________________________________
# activation_274 (Activation)     (None, 8, 8, 128)    0           batch_normalization_274[0][0]
# __________________________________________________________________________________________________
# conv2d_306 (Conv2D)             (None, 8, 8, 128)    147584      activation_274[0][0]
# __________________________________________________________________________________________________
# batch_normalization_275 (BatchN (None, 8, 8, 128)    512         conv2d_306[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 8, 8, 128)    0           batch_normalization_275[0][0]
# __________________________________________________________________________________________________
# conv2d_307 (Conv2D)             (None, 8, 8, 256)    33024       activation_275[0][0]
# __________________________________________________________________________________________________
# add_89 (Add)                    (None, 8, 8, 256)    0           add_88[0][0]
#                                                                  conv2d_307[0][0]
# __________________________________________________________________________________________________
# batch_normalization_276 (BatchN (None, 8, 8, 256)    1024        add_89[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 8, 8, 256)    0           batch_normalization_276[0][0]
# __________________________________________________________________________________________________
# conv2d_308 (Conv2D)             (None, 8, 8, 128)    32896       activation_276[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 8, 8, 128)    512         conv2d_308[0][0]
# __________________________________________________________________________________________________
# activation_277 (Activation)     (None, 8, 8, 128)    0           batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# conv2d_309 (Conv2D)             (None, 8, 8, 128)    147584      activation_277[0][0]
# __________________________________________________________________________________________________
# batch_normalization_278 (BatchN (None, 8, 8, 128)    512         conv2d_309[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 8, 8, 128)    0           batch_normalization_278[0][0]
# __________________________________________________________________________________________________
# conv2d_310 (Conv2D)             (None, 8, 8, 256)    33024       activation_278[0][0]
# __________________________________________________________________________________________________
# add_90 (Add)                    (None, 8, 8, 256)    0           add_89[0][0]
#                                                                  conv2d_310[0][0]
# __________________________________________________________________________________________________
# lastlayer (Conv2D)              (None, 8, 8, 10)     2570        add_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 8, 8, 10)     40          lastlayer[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 8, 8, 10)     0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_9 (AveragePoo (None, 1, 1, 10)     0           activation_279[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 10)           0           average_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# softmax_3 (Softmax)             (None, 10)           0           flatten_9[0][0]
# ==================================================================================================
# Total params: 848,018
# Trainable params: 843,294
# Non-trainable params: 4,724
# __________________________________________________________________________________________________
# ResNet29v2
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:84: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1), name="lastlayer")`

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)

# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Using real-time data augmentation.
# Epoch 1/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 92s 59ms/step - loss: 1.9426 - acc: 0.4689 - val_loss: 1.5995 - val_acc: 0.5591
#
# Epoch 00001: val_acc improved from -inf to 0.55910, saving model to /content/saved_models/cifar10_ResNet29v2_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.4731 - acc: 0.5986 - val_loss: 1.4804 - val_acc: 0.5900
#
# Epoch 00002: val_acc improved from 0.55910 to 0.59000, saving model to /content/saved_models/cifar10_ResNet29v2_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.2835 - acc: 0.6582 - val_loss: 1.7084 - val_acc: 0.5168
#
# Epoch 00003: val_acc did not improve from 0.59000
# Epoch 4/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.1660 - acc: 0.6958 - val_loss: 1.2975 - val_acc: 0.6429
#
# Epoch 00004: val_acc improved from 0.59000 to 0.64290, saving model to /content/saved_models/cifar10_ResNet29v2_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.0884 - acc: 0.7222 - val_loss: 1.0223 - val_acc: 0.7433
#
# Epoch 00005: val_acc improved from 0.64290 to 0.74330, saving model to /content/saved_models/cifar10_ResNet29v2_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.0262 - acc: 0.7402 - val_loss: 1.1885 - val_acc: 0.6992
#
# Epoch 00006: val_acc did not improve from 0.74330
# Epoch 7/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.9762 - acc: 0.7560 - val_loss: 1.3196 - val_acc: 0.6434
#
# Epoch 00007: val_acc did not improve from 0.74330
# Epoch 8/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.9345 - acc: 0.7695 - val_loss: 0.9404 - val_acc: 0.7614
#
# Epoch 00008: val_acc improved from 0.74330 to 0.76140, saving model to /content/saved_models/cifar10_ResNet29v2_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.9047 - acc: 0.7773 - val_loss: 1.0417 - val_acc: 0.7327
#
# Epoch 00009: val_acc did not improve from 0.76140
# Epoch 10/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.8752 - acc: 0.7878 - val_loss: 1.3211 - val_acc: 0.6492
#
# Epoch 00010: val_acc did not improve from 0.76140
# Epoch 11/50
# Learning rate:  0.001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.8518 - acc: 0.7939 - val_loss: 0.9510 - val_acc: 0.7605
#
# Epoch 00011: val_acc did not improve from 0.76140
# Epoch 12/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.7174 - acc: 0.8402 - val_loss: 0.6700 - val_acc: 0.8546
#
# Epoch 00012: val_acc improved from 0.76140 to 0.85460, saving model to /content/saved_models/cifar10_ResNet29v2_model.012.h5
# Epoch 13/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.6680 - acc: 0.8566 - val_loss: 0.6390 - val_acc: 0.8602
#
# Epoch 00013: val_acc improved from 0.85460 to 0.86020, saving model to /content/saved_models/cifar10_ResNet29v2_model.013.h5
# Epoch 14/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.6447 - acc: 0.8600 - val_loss: 0.6215 - val_acc: 0.8664
#
# Epoch 00014: val_acc improved from 0.86020 to 0.86640, saving model to /content/saved_models/cifar10_ResNet29v2_model.014.h5
# Epoch 15/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.6229 - acc: 0.8660 - val_loss: 0.6203 - val_acc: 0.8627
#
# Epoch 00015: val_acc did not improve from 0.86640
# Epoch 16/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.6056 - acc: 0.8703 - val_loss: 0.6118 - val_acc: 0.8650
#
# Epoch 00016: val_acc did not improve from 0.86640
# Epoch 17/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.5870 - acc: 0.8742 - val_loss: 0.6220 - val_acc: 0.8587
#
# Epoch 00017: val_acc did not improve from 0.86640
# Epoch 18/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.5758 - acc: 0.8775 - val_loss: 0.5838 - val_acc: 0.8729
#
# Epoch 00018: val_acc improved from 0.86640 to 0.87290, saving model to /content/saved_models/cifar10_ResNet29v2_model.018.h5
# Epoch 19/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.5606 - acc: 0.8813 - val_loss: 0.5993 - val_acc: 0.8640
#
# Epoch 00019: val_acc did not improve from 0.87290
# Epoch 20/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.5495 - acc: 0.8844 - val_loss: 0.5958 - val_acc: 0.8660
#
# Epoch 00020: val_acc did not improve from 0.87290
# Epoch 21/50
# Learning rate:  0.0001
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.5396 - acc: 0.8877 - val_loss: 0.5728 - val_acc: 0.8721
#
# Epoch 00021: val_acc did not improve from 0.87290
# Epoch 22/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.5174 - acc: 0.8935 - val_loss: 0.5481 - val_acc: 0.8801
#
# Epoch 00022: val_acc improved from 0.87290 to 0.88010, saving model to /content/saved_models/cifar10_ResNet29v2_model.022.h5
# Epoch 23/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.5104 - acc: 0.8973 - val_loss: 0.5474 - val_acc: 0.8810
#
# Epoch 00023: val_acc improved from 0.88010 to 0.88100, saving model to /content/saved_models/cifar10_ResNet29v2_model.023.h5
# Epoch 24/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.5077 - acc: 0.8968 - val_loss: 0.5448 - val_acc: 0.8824
#
# Epoch 00024: val_acc improved from 0.88100 to 0.88240, saving model to /content/saved_models/cifar10_ResNet29v2_model.024.h5
# Epoch 25/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.5049 - acc: 0.8986 - val_loss: 0.5437 - val_acc: 0.8821
#
# Epoch 00025: val_acc did not improve from 0.88240
# Epoch 26/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4995 - acc: 0.9008 - val_loss: 0.5434 - val_acc: 0.8819
#
# Epoch 00026: val_acc did not improve from 0.88240
# Epoch 27/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4979 - acc: 0.9006 - val_loss: 0.5398 - val_acc: 0.8828
#
# Epoch 00027: val_acc improved from 0.88240 to 0.88280, saving model to /content/saved_models/cifar10_ResNet29v2_model.027.h5
# Epoch 28/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4961 - acc: 0.9011 - val_loss: 0.5389 - val_acc: 0.8833
#
# Epoch 00028: val_acc improved from 0.88280 to 0.88330, saving model to /content/saved_models/cifar10_ResNet29v2_model.028.h5
# Epoch 29/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.4964 - acc: 0.9008 - val_loss: 0.5397 - val_acc: 0.8810
#
# Epoch 00029: val_acc did not improve from 0.88330
# Epoch 30/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.4928 - acc: 0.9025 - val_loss: 0.5344 - val_acc: 0.8844
#
# Epoch 00030: val_acc improved from 0.88330 to 0.88440, saving model to /content/saved_models/cifar10_ResNet29v2_model.030.h5
# Epoch 31/50
# Learning rate:  1e-05
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.4951 - acc: 0.9013 - val_loss: 0.5346 - val_acc: 0.8848
#
# Epoch 00031: val_acc improved from 0.88440 to 0.88480, saving model to /content/saved_models/cifar10_ResNet29v2_model.031.h5
# Epoch 32/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4913 - acc: 0.9011 - val_loss: 0.5342 - val_acc: 0.8842
#
# Epoch 00032: val_acc did not improve from 0.88480
# Epoch 33/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4871 - acc: 0.9038 - val_loss: 0.5377 - val_acc: 0.8839
#
# Epoch 00033: val_acc did not improve from 0.88480
# Epoch 34/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.4868 - acc: 0.9042 - val_loss: 0.5376 - val_acc: 0.8847
#
# Epoch 00034: val_acc did not improve from 0.88480
# Epoch 35/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.4921 - acc: 0.9011 - val_loss: 0.5357 - val_acc: 0.8855
#
# Epoch 00035: val_acc improved from 0.88480 to 0.88550, saving model to /content/saved_models/cifar10_ResNet29v2_model.035.h5
# Epoch 36/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4883 - acc: 0.9025 - val_loss: 0.5352 - val_acc: 0.8850
#
# Epoch 00036: val_acc did not improve from 0.88550
# Epoch 37/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.4889 - acc: 0.9024 - val_loss: 0.5372 - val_acc: 0.8838
#
# Epoch 00037: val_acc did not improve from 0.88550
# Epoch 38/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4884 - acc: 0.9033 - val_loss: 0.5350 - val_acc: 0.8842
#
# Epoch 00038: val_acc did not improve from 0.88550
# Epoch 39/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.4861 - acc: 0.9033 - val_loss: 0.5346 - val_acc: 0.8852
#
# Epoch 00039: val_acc did not improve from 0.88550
# Epoch 40/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 70s 45ms/step - loss: 0.4855 - acc: 0.9047 - val_loss: 0.5347 - val_acc: 0.8850
#
# Epoch 00040: val_acc did not improve from 0.88550
# Epoch 41/50
# Learning rate:  1e-06
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.4839 - acc: 0.9060 - val_loss: 0.5331 - val_acc: 0.8838
#
# Epoch 00041: val_acc did not improve from 0.88550
# Epoch 42/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.4867 - acc: 0.9042 - val_loss: 0.5341 - val_acc: 0.8844
#
# Epoch 00042: val_acc did not improve from 0.88550
# Epoch 43/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.4855 - acc: 0.9042 - val_loss: 0.5364 - val_acc: 0.8847
#
# Epoch 00043: val_acc did not improve from 0.88550
# Epoch 44/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.4872 - acc: 0.9034 - val_loss: 0.5338 - val_acc: 0.8855
#
# Epoch 00044: val_acc did not improve from 0.88550
# Epoch 45/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4850 - acc: 0.9056 - val_loss: 0.5354 - val_acc: 0.8845
#
# Epoch 00045: val_acc did not improve from 0.88550
# Epoch 46/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 71s 45ms/step - loss: 0.4889 - acc: 0.9037 - val_loss: 0.5344 - val_acc: 0.8844
#
# Epoch 00046: val_acc did not improve from 0.88550
# Epoch 47/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4812 - acc: 0.9042 - val_loss: 0.5341 - val_acc: 0.8843
#
# Epoch 00047: val_acc did not improve from 0.88550
# Epoch 48/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 72s 46ms/step - loss: 0.4830 - acc: 0.9055 - val_loss: 0.5353 - val_acc: 0.8848
#
# Epoch 00048: val_acc did not improve from 0.88550
# Epoch 49/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4836 - acc: 0.9059 - val_loss: 0.5335 - val_acc: 0.8845
#
# Epoch 00049: val_acc did not improve from 0.88550
# Epoch 50/50
# Learning rate:  5e-07
# 1563/1563 [==============================] - 71s 46ms/step - loss: 0.4834 - acc: 0.9050 - val_loss: 0.5333 - val_acc: 0.8841
#
# Epoch 00050: val_acc did not improve from 0.88550
# 10000/10000 [==============================] - 3s 283us/step
# Test loss: 0.5332523745536805
# Test accuracy: 0.8841

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive 
from google.colab import auth 
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()                       
drive = GoogleDrive(gauth)
model.save('EIP4 Assignment 4B.h5')
model_file = drive.CreateFile({'title' : 'EIP4 Assignment 4B.h5'})                       
model_file.SetContentFile('EIP4 Assignment 4B.h5')                      
model_file.Upload()
drive.CreateFile({'id': model_file.get('id')})
# Out:
# GoogleDriveFile({'id': '1GRTFcySAmTO2h1CkuXatiowkQm2FGVBM'})

# %%
file_obj = drive.CreateFile({'id': '1GRTFcySAmTO2h1CkuXatiowkQm2FGVBM'})                       
file_obj.GetContentFile('EIP4 Assignment 4B.h5')
from numpy import loadtxt
from keras.models import load_model
model = load_model('EIP4 Assignment 4B.h5')

# %%
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
import keras.backend as K
import numpy as np
import cv2
import sys

# %%
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
test_features[0].shape
# Out:
# (32, 32, 3)

# %%
class_names = ['airplane','automobile','bird','cat','deer',  # Plotting 10 images of different classes present in CIFAR10
               'dog','frog','horse','ship','truck']
from google.colab.patches import cv2_imshow
gradcam_test_features= [ test_features[17], test_features[12], test_features[21], test_features[29], test_features[17], test_features[12], test_features[21], test_features[29], test_features[17], test_features[12]]
for idx in range(10):
  img=gradcam_test_features[idx]
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  
  x = preprocess_input(x)
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("lastlayer")
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
for i in range(10):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

    heatmap = np.mean(conv_layer_output_value, axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= np.max(heatmap)
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
    Original_img=new_image=cv2.resize(img,(128,128))
    cv2_imshow(Original_img)
    superimposed_img=cv2.resize(superimposed_img,(128,128))
    cv2_imshow(superimposed_img)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538FA4BE0>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F9BEB8>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3ED68>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3ED68>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3ED68>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3ED68>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3ED68>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3ED68>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3ED68>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in true_divide
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF538F3EB38>
